# %%
import pandas as pd

df = pd.read_csv('HousePricePrediction.csv')

df = df.dropna(subset=['SalePrice'])
df = df.drop('Id', axis=1)

for col in df.select_dtypes(include=['float64', 'int64']).columns:
    df[col] = df[col].fillna(df[col].median())
    
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].fillna(df[col].mode()[0])

df_encoded = pd.get_dummies(df, drop_first=True)

df_encoded.to_csv('cleaned_dataset.csv', index=False)

print("Success! Your cleaned data has been saved as 'cleaned_dataset.csv'.")
# Out:
# Success! Your cleaned data has been saved as 'cleaned_dataset.csv'.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

df = pd.read_csv('HousePricePrediction.csv')

df = df.dropna(subset=['SalePrice'])
df = df.drop('Id', axis=1)

for col in df.select_dtypes(include=['float64', 'int64']).columns:
    df[col] = df[col].fillna(df[col].median())
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].fillna(df[col].mode()[0])

df_encoded = pd.get_dummies(df, drop_first=True)

X = df_encoded.drop('SalePrice', axis=1)
y = df_encoded['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print("Task 1: Train-Test Split")
print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print()

model = LinearRegression()
model.fit(X_train, y_train)

print("Task 2: Model Training")
print("Model trained successfully.")
print()

y_pred = model.predict(X_test)

print("Task 3: Model Prediction")
print("First 5 predictions:", y_pred[:5].round(2))
print()

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Task 4: Model Evaluation")
print("MAE:", round(mae, 2))
print("MSE:", round(mse, 2))
print("RMSE:", round(rmse, 2))
print("R2 Score:", round(r2, 4))
# Out:
# Task 1: Train-Test Split
# Train shape: (1168, 33)
# Test shape: (292, 33)
#
# Task 2: Model Training
# Model trained successfully.
#
# Task 3: Model Prediction
# First 5 predictions: [168844.2  243627.93 114499.47 157672.75 254809.73]
#
# Task 4: Model Evaluation
# MAE: 34122.85
# MSE: 2918458029.59
# RMSE: 54022.75
# R2 Score: 0.6195
